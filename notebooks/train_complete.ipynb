# %% [markdown]
# <a href="https://colab.research.google.com/github/manamendraJN/temporal-fashion-intelligence-system/blob/Manamendra-J.N-(body-measurement-ai)/notebooks/train_complete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
# System setup
import sys
import os
from datetime import datetime, UTC

print("="*80)
print("BODY MEASUREMENT AI - ACADEMIC RESEARCH PROJECT")
print("="*80)
print(f"Student: manamendraJN")
print(f"Date: {datetime.now(UTC).strftime('%Y-%m-%d %H:%M:%S')} UTC")
print(f"Python: {sys.version.split()[0]}")

# Install packages - let pip resolve dependencies automatically
print("\n📦 Installing required packages...")
# !pip install -q timm albumentations gdown

print("✅ Packages installed successfully\n")

# Core libraries
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision
import timm

# Data processing
import numpy as np
import pandas as pd
import cv2
from PIL import Image
from pathlib import Path

# Augmentation
import albumentations as A
from albumentations.pytorch import ToTensorV2

# Utilities
from tqdm.auto import tqdm
import json
import yaml
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Set style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

print(f"PyTorch: {torch.__version__}")
print(f"NumPy: {np.__version__}")
import sklearn
print(f"Scikit-learn: {sklearn.__version__}")
print(f"Albumentations: {A.__version__}")
print(f"timm: {timm.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    print("⚠️  WARNING: No GPU detected. Training will be slow.")
    print("Please enable GPU: Runtime → Change runtime type → GPU")

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"\nUsing device: {device}")

# Reproducibility
SEED = 42
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
np.random.seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

print(f"Random seed set to: {SEED}")
print("="*80)
# Out:
# ...
# BODY MEASUREMENT AI - ACADEMIC RESEARCH PROJECT
# ...
# Student: manamendraJN
# Date: 2025-11-17 09:59:34 UTC
# Python: 3.12.12
#
# 📦 Installing required packages...
# ✅ Packages installed successfully
#
# PyTorch: 2.8.0+cu126
# NumPy: 2.0.2
# Scikit-learn: 1.6.1
# Albumentations: 2.0.8
# timm: 1.0.22
# CUDA Available: True
# GPU: Tesla T4
# GPU Memory: 15.83 GB
#
# Using device: cuda
# Random seed set to: 42
# ...
